# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import timedelta, time, datetime


import warnings
from IPython.core.display import display, HTML
warnings.filterwarnings("ignore") # suppress warnings because theyre annoying and i like living on the edge
pd.set_option('display.max_columns',100) # so i can see all columns
np.set_printoptions(linewidth = 220) # increase numpy array print
display(HTML("<style>.container { width:80% !important; }</style>")) # widen jupyter notebook blocks
# Out:
# <style>.container { width:80% !important; }</style>

# %%
conn_cred = {
    "dbservername":"localhost",
    "dbname":"main_schema",
    "dbuser":"minx",
    "dbpassword":"!xobILE!!!111!"
}

# %%
import pymysql as MySQLdb

# %%
def mysql_conn(db_conn_info):
    '''
    Call to connect to the database
    '''
    try:
        dbconn_ = MySQLdb.connect(host=db_conn_info['dbservername'],
                    db = db_conn_info['dbname'],
                    user = db_conn_info['dbuser'],
                    passwd = db_conn_info['dbpassword']
                    )
        cursor_ = dbconn_.cursor()
        return dbconn_, cursor_

    except Exception as e:
        print('Error: ' + str(e))

def db_conn_close(dbconn, cursor):
    # closing connections to free up sockets
    dbconn.commit()
    cursor.close()
    dbconn.close()
    
    
def run_query(creds, query):
    conn, cursor = mysql_conn(creds)

    try:
        cursor.execute(query)
        rows = cursor.fetchall()
    except Exception as e:
        print('Error in running query: ' + str(e))
    finally:
        db_conn_close(conn, cursor)
    return rows

# %%
query_ = 'SELECT * FROM {dbname}.bar_15min'.format(dbname = conn_cred['dbname'])
rows = run_query(conn_cred,query_)

# %%
rows
# Out:
# (('AAPL',
#   datetime.datetime(2020, 11, 6, 6, 30),
#   Decimal('118.320'),
#   Decimal('116.650'),
#   Decimal('118.640'),
#   Decimal('116.300'),
#   Decimal('106119')),
#  ('AAPL',
#   datetime.datetime(2020, 11, 6, 6, 45),
#   Decimal('116.650'),
#   Decimal('116.290'),
#   Decimal('116.910'),
#   Decimal('116.130'),
#   Decimal('54342')),
#  ('AAPL',
#   datetime.datetime(2020, 11, 6, 7, 0),
#   Decimal('116.300'),
#   Decimal('117.010'),
#   Decimal('117.120'),
#   Decimal('116.130'),
#   Decimal('46862')),
#  ('AAPL',
#   datetime.datetime(2020, 11, 6, 7, 15),
#   Decimal('117.010'),
#   Decimal('117.470'),
#   Decimal('117.600'),
#   Decimal('116.830'),
#   Decimal('37682')),
#  ('AAPL',
#   datetime.datetime(2020, 11, 6, 7, 30),
#   Decimal('117.460'),
#   Decimal('117.640'),
#   Decimal('117.700'),
#   Decimal('117.140'),
#   Decimal('30883')),
#  ('AAPL',
#   datetime.datetime(2020, 11, 6, 7, 45),
#   Decimal('117.640'),
#   Decimal('117.420'),
#   Decimal('117.900'),
#   Decimal('117.260'),
#   Decimal('32868')),
#  ('AAPL',
#   datetime.datetime(2020, 11, 6, 8, 0),
#   Decimal('117.410'),
#   Decimal('117.830'),
#   Decimal('118.100'),
#   Decimal('117.300'),
#   Decimal('33715')),
#  ('AAPL',
#   datetime.datetime(2020, 11, 6, 8, 15),
#   Decimal('117.850'),
#   Decimal('118.130'),
#   Decimal('118.140'),
#   Decimal('117.650'),
#   Decimal('27091')),
#  ('AAPL',
#   datetime.datetime(2020, 11, 6, 8, 30),
#   Decimal('118.130'),
#   Decimal('118.380'),
#   Decimal('118.450'),
#   Decimal('118.020'),
#   Decimal('26864')),
#  ('AAPL',
#   datetime.datetime(2020, 11, 6, 8, 45),
#   Decimal('118.370'),
#   Decimal('118.740'),
#   Decimal('118.820'),
#   Decimal('118.300'),
#   Decimal('33115')),
#  ('AAPL',
#   datetime.datetime(2020, 11, 6, 9, 0),
#   Decimal('118.740'),
#   Decimal('118.780'),
#   Decimal('119.190'),
#   Decimal('118.660'),
#   Decimal('37406')),
#  ('AAPL',
#   datetime.datetime(2020, 11, 6, 9, 15),
#   Decimal('118.780'),
#   Decimal('118.430'),
#   Decimal('118.840'),
#   Decimal('118.280'),
#   Decimal('24082')),
#  ('AAPL',
#   datetime.datetime(2020, 11, 6, 9, 30),
#   Decimal('118.440'),
#   Decimal('118.880'),
#   Decimal('118.890'),
#   Decimal('118.430'),
#   Decimal('23618')),
#  ('AAPL',
#   datetime.datetime(2020, 11, 6, 9, 45),
#   Decimal('118.880'),
#   Decimal('118.880'),
#   Decimal('118.970'),
#   Decimal('118.620'),
#   Decimal('19691')),
#  ('AAPL',
#   datetime.datetime(2020, 11, 6, 10, 0),
#   Decimal('118.890'),
#   Decimal('119.150'),
#   Decimal('119.160'),
#   Decimal('118.830'),
#   Decimal('18323')),
#  ('AAPL',
#   datetime.datetime(2020, 11, 6, 10, 15),
#   Decimal('119.150'),
#   Decimal('119.110'),
#   Decimal('119.200'),
#   Decimal('118.880'),
#   Decimal('18587')),
#  ('AAPL',
#   datetime.datetime(2020, 11, 6, 10, 30),
#   Decimal('119.110'),
#   Decimal('118.940'),
#   Decimal('119.120'),
#   Decimal('118.920'),
#   Decimal('14422')),
#  ('AAPL',
#   datetime.datetime(2020, 11, 6, 10, 45),
#   Decimal('118.950'),
#   Decimal('119.000'),
#   Decimal('119.080'),
#   Decimal('118.840'),
#   Decimal('15156')),
#  ('AAPL',
#   datetime.datetime(2020, 11, 6, 11, 0),
#   Decimal('119.000'),
#   Decimal('119.100'),
#   Decimal('119.130'),
#   Decimal('118.850'),
#   Decimal('15897')),
#  ('AAPL',
#   datetime.datetime(2020, 11, 6, 11, 15),
#   Decimal('119.110'),
#   Decimal('118.890'),
#   Decimal('119.170'),
#   Decimal('118.860'),
#   Decimal('16101')),
#  ('AAPL',
#   datetime.datetime(2020, 11, 6, 11, 30),
#   Decimal('118.890'),
#   Decimal('118.500'),
#   Decimal('119.040'),
#   Decimal('118.480'),
#   Decimal('25465')),
#  ('AAPL',
#   datetime.datetime(2020, 11, 6, 11, 45),
#   Decimal('118.500'),
#   Decimal('118.470'),
#   Decimal('118.550'),
#   Decimal('118.220'),
#   Decimal('27265')),
#  ('AAPL',
#   datetime.datetime(2020, 11, 6, 12, 0),
#   Decimal('118.470'),
#   Decimal('118.480'),
#   Decimal('118.560'),
#   Decimal('118.130'),
#   Decimal('25681')),
#  ('AAPL',
#   datetime.datetime(2020, 11, 6, 12, 15),
#   Decimal('118.480'),
#   Decimal('118.370'),
#   Decimal('118.570'),
#   Decimal('118.090'),
#   Decimal('30669')),
#  ('AAPL',
#   datetime.datetime(2020, 11, 6, 12, 30),
#   Decimal('118.370'),
#   Decimal('118.850'),
#   Decimal('118.860'),
#   Decimal('118.260'),
#   Decimal('31591')),
#  ('AAPL',
#   datetime.datetime(2020, 11, 6, 12, 45),
#   Decimal('118.850'),
#   Decimal('118.690'),
#   Decimal('119.060'),
#   Decimal('118.400'),
#   Decimal('61651')),
#  ('TSLA',
#   datetime.datetime(2020, 11, 6, 6, 30),
#   Decimal('436.100'),
#   Decimal('428.300'),
#   Decimal('436.570'),
#   Decimal('426.900'),
#   Decimal('19613')),
#  ('TSLA',
#   datetime.datetime(2020, 11, 6, 6, 45),
#   Decimal('428.280'),
#   Decimal('425.640'),
#   Decimal('429.200'),
#   Decimal('424.280'),
#   Decimal('15433')),
#  ('TSLA',
#   datetime.datetime(2020, 11, 6, 7, 0),
#   Decimal('425.740'),
#   Decimal('428.000'),
#   Decimal('428.570'),
#   Decimal('424.950'),
#   Decimal('10636')),
#  ('TSLA',
#   datetime.datetime(2020, 11, 6, 7, 15),
#   Decimal('427.970'),
#   Decimal('429.480'),
#   Decimal('430.020'),
#   Decimal('427.400'),
#   Decimal('7230')),
#  ('TSLA',
#   datetime.datetime(2020, 11, 6, 7, 30),
#   Decimal('429.380'),
#   Decimal('431.060'),
#   Decimal('431.250'),
#   Decimal('428.730'),
#   Decimal('6875')),
#  ('TSLA',
#   datetime.datetime(2020, 11, 6, 7, 45),
#   Decimal('431.100'),
#   Decimal('430.690'),
#   Decimal('433.130'),
#   Decimal('430.300'),
#   Decimal('8480')),
#  ('TSLA',
#   datetime.datetime(2020, 11, 6, 8, 0),
#   Decimal('430.610'),
#   Decimal('430.730'),
#   Decimal('432.310'),
#   Decimal('429.750'),
#   Decimal('4921')),
#  ('TSLA',
#   datetime.datetime(2020, 11, 6, 8, 15),
#   Decimal('430.800'),
#   Decimal('430.700'),
#   Decimal('430.890'),
#   Decimal('429.000'),
#   Decimal('4721')),
#  ('TSLA',
#   datetime.datetime(2020, 11, 6, 8, 30),
#   Decimal('430.450'),
#   Decimal('430.540'),
#   Decimal('432.200'),
#   Decimal('429.780'),
#   Decimal('4376')),
#  ('TSLA',
#   datetime.datetime(2020, 11, 6, 8, 45),
#   Decimal('430.460'),
#   Decimal('430.600'),
#   Decimal('432.100'),
#   Decimal('429.880'),
#   Decimal('3475')),
#  ('TSLA',
#   datetime.datetime(2020, 11, 6, 9, 0),
#   Decimal('430.680'),
#   Decimal('430.830'),
#   Decimal('432.430'),
#   Decimal('430.300'),
#   Decimal('3952')),
#  ('TSLA',
#   datetime.datetime(2020, 11, 6, 9, 15),
#   Decimal('430.740'),
#   Decimal('429.500'),
#   Decimal('430.860'),
#   Decimal('429.300'),
#   Decimal('3692')),
#  ('TSLA',
#   datetime.datetime(2020, 11, 6, 9, 30),
#   Decimal('429.570'),
#   Decimal('428.830'),
#   Decimal('430.310'),
#   Decimal('428.300'),
#   Decimal('3935')),
#  ('TSLA',
#   datetime.datetime(2020, 11, 6, 9, 45),
#   Decimal('428.750'),
#   Decimal('429.150'),
#   Decimal('429.730'),
#   Decimal('428.120'),
#   Decimal('2856')),
#  ('TSLA',
#   datetime.datetime(2020, 11, 6, 10, 0),
#   Decimal('429.180'),
#   Decimal('429.960'),
#   Decimal('430.250'),
#   Decimal('429.000'),
#   Decimal('3096')),
#  ('TSLA',
#   datetime.datetime(2020, 11, 6, 10, 15),
#   Decimal('429.960'),
#   Decimal('429.930'),
#   Decimal('429.970'),
#   Decimal('428.780'),
#   Decimal('2637')),
#  ('TSLA',
#   datetime.datetime(2020, 11, 6, 10, 30),
#   Decimal('429.800'),
#   Decimal('429.140'),
#   Decimal('430.460'),
#   Decimal('429.120'),
#   Decimal('2510')),
#  ('TSLA',
#   datetime.datetime(2020, 11, 6, 10, 45),
#   Decimal('429.200'),
#   Decimal('429.480'),
#   Decimal('429.580'),
#   Decimal('428.350'),
#   Decimal('3025')),
#  ('TSLA',
#   datetime.datetime(2020, 11, 6, 11, 0),
#   Decimal('429.550'),
#   Decimal('429.440'),
#   Decimal('429.820'),
#   Decimal('428.800'),
#   Decimal('2332')),
#  ('TSLA',
#   datetime.datetime(2020, 11, 6, 11, 15),
#   Decimal('429.420'),
#   Decimal('429.100'),
#   Decimal('430.250'),
#   Decimal('428.970'),
#   Decimal('3229')),
#  ('TSLA',
#   datetime.datetime(2020, 11, 6, 11, 30),
#   Decimal('429.100'),
#   Decimal('429.360'),
#   Decimal('430.520'),
#   Decimal('429.090'),
#   Decimal('2998')),
#  ('TSLA',
#   datetime.datetime(2020, 11, 6, 11, 45),
#   Decimal('429.420'),
#   Decimal('428.980'),
#   Decimal('429.470'),
#   Decimal('428.650'),
#   Decimal('2615')),
#  ('TSLA',
#   datetime.datetime(2020, 11, 6, 12, 0),
#   Decimal('428.930'),
#   Decimal('428.340'),
#   Decimal('428.930'),
#   Decimal('427.280'),
#   Decimal('5359')),
#  ('TSLA',
#   datetime.datetime(2020, 11, 6, 12, 15),
#   Decimal('428.380'),
#   Decimal('428.060'),
#   Decimal('428.480'),
#   Decimal('426.760'),
#   Decimal('3896')),
#  ('TSLA',
#   datetime.datetime(2020, 11, 6, 12, 30),
#   Decimal('428.070'),
#   Decimal('429.540'),
#   Decimal('429.640'),
#   Decimal('427.580'),
#   Decimal('5117')),
#  ('TSLA',
#   datetime.datetime(2020, 11, 6, 12, 45),
#   Decimal('429.530'),
#   Decimal('429.920'),
#   Decimal('430.970'),
#   Decimal('429.350'),
#   Decimal('9507')))

# %%
pd.DataFrame(rows, columns = ['symbol','datetime','open','close','high','low','volume'])
# Out:
#    symbol            datetime     open    close     high      low  volume
# 0    AAPL 2020-11-06 06:30:00  118.320  116.650  118.640  116.300  106119
# 1    AAPL 2020-11-06 06:45:00  116.650  116.290  116.910  116.130   54342
# 2    AAPL 2020-11-06 07:00:00  116.300  117.010  117.120  116.130   46862
# 3    AAPL 2020-11-06 07:15:00  117.010  117.470  117.600  116.830   37682
# 4    AAPL 2020-11-06 07:30:00  117.460  117.640  117.700  117.140   30883
# 5    AAPL 2020-11-06 07:45:00  117.640  117.420  117.900  117.260   32868
# 6    AAPL 2020-11-06 08:00:00  117.410  117.830  118.100  117.300   33715
# 7    AAPL 2020-11-06 08:15:00  117.850  118.130  118.140  117.650   27091
# 8    AAPL 2020-11-06 08:30:00  118.130  118.380  118.450  118.020   26864
# 9    AAPL 2020-11-06 08:45:00  118.370  118.740  118.820  118.300   33115
# 10   AAPL 2020-11-06 09:00:00  118.740  118.780  119.190  118.660   37406
