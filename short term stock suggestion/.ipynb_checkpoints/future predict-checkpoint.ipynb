# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import urllib.request 

work_dir = 'D:/5_us_txt/data/5 min/us/nasdaq stocks/'
# work_dir = '/home/minx/Documents/stock_data'

# %%
import glob

# for non-specific stock choices
dir_ = glob.glob(work_dir + '*/*') # all nasdaq stocks
df_raw = pd.read_csv(dir_[89])

# %%
df_raw = pd.read_csv(work_dir + '1/aapl.us.txt')
df_raw.columns = ['ticker','period','date','time','open',
              'high','low','close','vol','openint']

# %%
df_raw
# Out:
#        ticker  period      date    time     open     high     low    close  \
# 0     AAPL.US       5  20201015  153000  118.520  119.580  117.95  119.130
# 1     AAPL.US       5  20201015  153500  119.120  119.960  119.02  119.500
# 2     AAPL.US       5  20201015  154000  119.510  120.070  119.43  120.030
# 3     AAPL.US       5  20201015  154500  120.040  120.040  119.66  119.830
# 4     AAPL.US       5  20201015  155000  119.840  120.430  119.72  120.320
# ...       ...     ...       ...     ...      ...      ...     ...      ...
# 2739  AAPL.US       5  20201204  213500  122.035  122.035  121.90  121.960
# 2740  AAPL.US       5  20201204  214000  121.960  122.150  121.88  122.015
# 2741  AAPL.US       5  20201204  214500  122.010  122.080  121.97  122.030
# 2742  AAPL.US       5  20201204  215000  122.026  122.130  121.98  122.120
# 2743  AAPL.US       5  20201204  215500  122.120  122.300  122.06  122.250
#
#           vol  openint
# 0     5328872        0
# 1     2227343        0
# 2     1691062        0
# 3     1734908        0
# 4     2151231        0
# ...       ...      ...
# 2739   670605        0
# 2740  1006254        0
# 2741   956046        0
# 2742  1312050        0
# 2743  7574832        0
#
# [2744 rows x 10 columns]

# %%
from utils import *

rsi_list = mult_rsi(df_raw.open.values)
macd_list, signal_list = mult_macd(df_raw.open.values)

# %%
print(len(rsi_list), len(macd_list), len(signal_list))
# Out:
# 2734 2718 2710

# %%
names = ['rsi','macd','signal']
lists = [rsi_list, macd_list, signal_list]
for i in range(3):
    lead_ = [np.nan] * (df_raw.shape[0] - len(lists[i]))
    lead_.extend(lists[i])
    df_raw[names[i]] = lead_

# %%
df_raw.head(30)
# Out:
#      ticker  period      date    time    open    high     low   close  \
# 0   AAPL.US       5  20201015  153000  118.52  119.58  117.95  119.13
# 1   AAPL.US       5  20201015  153500  119.12  119.96  119.02  119.50
# 2   AAPL.US       5  20201015  154000  119.51  120.07  119.43  120.03
# 3   AAPL.US       5  20201015  154500  120.04  120.04  119.66  119.83
# 4   AAPL.US       5  20201015  155000  119.84  120.43  119.72  120.32
# 5   AAPL.US       5  20201015  155500  120.31  120.36  119.85  119.99
# 6   AAPL.US       5  20201015  160000  119.97  120.17  119.52  119.58
# 7   AAPL.US       5  20201015  160500  119.59  119.86  119.19  119.24
# 8   AAPL.US       5  20201015  161000  119.23  119.45  119.19  119.29
# 9   AAPL.US       5  20201015  161500  119.28  119.86  119.00  119.71
# 10  AAPL.US       5  20201015  162000  119.70  119.81  119.44  119.68
# 11  AAPL.US       5  20201015  162500  119.68  119.74  119.29  119.36
# 12  AAPL.US       5  20201015  163000  119.33  119.48  119.09  119.20
# 13  AAPL.US       5  20201015  163500  119.20  119.31  118.91  119.27
# 14  AAPL.US       5  20201015  164000  119.26  119.41  118.86  118.98
# 15  AAPL.US       5  20201015  164500  118.98  119.09  118.81  119.01
# 16  AAPL.US       5  20201015  165000  119.03  119.30  118.93  119.20
# 17  AAPL.US       5  20201015  165500  119.20  119.64  119.01  119.54
# 18  AAPL.US       5  20201015  170000  119.53  119.70  118.96  119.18
# 19  AAPL.US       5  20201015  170500  119.17  119.64  119.12  119.54
# 20  AAPL.US       5  20201015  171000  119.54  119.59  119.28  119.57
# 21  AAPL.US       5  20201015  171500  119.56  119.84  119.56  119.78
# 22  AAPL.US       5  20201015  172000  119.78  119.90  119.64  119.76
# 23  AAPL.US       5  20201015  172500  119.77  119.84  119.51  119.64
# 24  AAPL.US       5  20201015  173000  119.63  119.95  119.57  119.79
# 25  AAPL.US       5  20201015  173500  119.79  119.91  119.62  119.88
# 26  AAPL.US       5  20201015  174000  119.87  120.00  119.83  119.89
# 27  AAPL.US       5  20201015  174500  119.89  120.02  119.79  119.87
# 28  AAPL.US       5  20201015  175000  119.87  120.07  119.54  119.96
# 29  AAPL.US       5  20201015  175500  119.97  120.18  119.83  120.08
#
#         vol  openint        rsi      macd  signal
# 0   5328872        0        NaN       NaN     NaN
# 1   2227343        0        NaN       NaN     NaN
# 2   1691062        0        NaN       NaN     NaN
# 3   1734908        0        NaN       NaN     NaN
# 4   2151231        0        NaN       NaN     NaN
# 5   1696847        0        NaN       NaN     NaN
# 6   1682806        0        NaN       NaN     NaN
# 7   1791776        0        NaN       NaN     NaN
# 8   1471070        0        NaN       NaN     NaN
# 9   1954576        0        NaN       NaN     NaN
# 10  1306535        0  66.247407       NaN     NaN
# 11  1288047        0  65.807974       NaN     NaN
# 12  1201082        0  58.209841       NaN     NaN
# 13  1522083        0  55.530613       NaN     NaN
# 14  1303724        0  56.568268       NaN     NaN
# 15  1288487        0  50.393360       NaN     NaN
# 16  1060090        0  51.457591       NaN     NaN
# 17  1373439        0  55.139307       NaN     NaN
# 18  1318901        0  61.513950       NaN     NaN
# 19  1027430        0  52.378816       NaN     NaN
# 20   849880        0  59.357099       NaN     NaN
# 21  1279158        0  59.715818       NaN     NaN
# 22  1103594        0  63.684858       NaN     NaN
# 23  1060738        0  63.365266       NaN     NaN
# 24   833626        0  58.727804       NaN     NaN
# 25   849844        0  62.276806       NaN     NaN
# 26   891403        0  64.017049 -0.008405     NaN
# 27   838261        0  64.477615  0.023063     NaN
# 28  1190143        0  63.561094  0.045859     NaN
# 29  1200871        0  66.257186  0.071174     NaN

# %%
from scipy.ndimage.interpolation import shift

n_history = 6
for i in range(n_history):
    df_raw['open_shift_' + str(i)] = shift(df_raw['open'].values, i, cval = np.nan)

# %%
for i in range(n_history - 1):
    df_raw['shift_prop' + str(i)] = (df_raw['open'] - df_raw['open_shift_' + str(i)]) / df_raw['open_shift_' + str(i)]

# %%
df_raw
# Out:
#        ticker  period      date    time     open     high     low    close  \
# 0     AAPL.US       5  20201015  153000  118.520  119.580  117.95  119.130
# 1     AAPL.US       5  20201015  153500  119.120  119.960  119.02  119.500
# 2     AAPL.US       5  20201015  154000  119.510  120.070  119.43  120.030
# 3     AAPL.US       5  20201015  154500  120.040  120.040  119.66  119.830
# 4     AAPL.US       5  20201015  155000  119.840  120.430  119.72  120.320
# ...       ...     ...       ...     ...      ...      ...     ...      ...
# 2739  AAPL.US       5  20201204  213500  122.035  122.035  121.90  121.960
# 2740  AAPL.US       5  20201204  214000  121.960  122.150  121.88  122.015
# 2741  AAPL.US       5  20201204  214500  122.010  122.080  121.97  122.030
# 2742  AAPL.US       5  20201204  215000  122.026  122.130  121.98  122.120
# 2743  AAPL.US       5  20201204  215500  122.120  122.300  122.06  122.250
#
#           vol  openint        rsi      macd    signal  label  open_shift_1  \
# 0     5328872        0        NaN       NaN       NaN    1.0           NaN
# 1     2227343        0        NaN       NaN       NaN    1.0       118.520
# 2     1691062        0        NaN       NaN       NaN    1.0       119.120
# 3     1734908        0        NaN       NaN       NaN    0.0       119.510
# 4     2151231        0        NaN       NaN       NaN    1.0       120.040
# ...       ...      ...        ...       ...       ...    ...           ...
# 2739   670605        0  52.512853  0.020100  0.007046    0.0       122.010
# 2740  1006254        0  44.983622  0.013349  0.008306    1.0       122.035
# 2741   956046        0  50.323723  0.011896  0.009024    1.0       121.960
# 2742  1312050        0  52.000120  0.011898  0.009599    1.0       122.010
# 2743  7574832        0  60.757076  0.019263  0.011532    NaN       122.026
#
#       open_shift_0  open_shift_2  open_shift_3  open_shift_4  shift_prop
# 0          118.520           NaN           NaN           NaN         NaN
# 1          119.120           NaN           NaN           NaN    0.005062
# 2          119.510       118.520           NaN           NaN    0.003274
# 3          120.040       119.120       118.520           NaN    0.004435
# 4          119.840       119.510       119.120       118.520   -0.001666
# ...            ...           ...           ...           ...         ...
# 2739       122.035       122.035       122.035       122.110    0.000205
# 2740       121.960       122.010       122.035       122.035   -0.000615
# 2741       122.010       122.035       122.010       122.035    0.000410
# 2742       122.026       121.960       122.035       122.010    0.000131
# 2743       122.120       122.010       121.960       122.035    0.000770
#
# [2744 rows x 20 columns]

# %%
delta = df_raw['open'].values[1:] - df_raw['open'].values[:-1]
label = delta > 0
label = np.append(label, [np.nan])
df_raw['label'] = label

# %%
df = df_raw[~df_raw['signal'].isna()].copy();
df = df.iloc[:-1]

# %%
xcols = ['time','open','rsi','macd','signal']
ycol = 'label'
rf_build(df, xcols, ycol, how_split = 'sequential', disp_conf_mat = True)
# Out:
#
#          pred
#          0.0   1.0
# true 0.0 214   46
#      1.0 233   49
#                      Measure   Value
# 0                   Accuracy  0.4852
# 1              Precision/PPV  0.5158
# 2     Sensitivity/TPR/Recall  0.1738
# 3            Specificity/TNR  0.8231
# 4                 Error Rate  0.5148
# 5  False Positive Rate (FPR)  0.1769
# 6                    F-Score  0.2599
# Max F-Score (68.45%) at threshold = 0.0
# Summary at Max F-Score
#
#          pred
#          0.0   1.0
# true 0.0 0     260
#      1.0 0     282
#                      Measure   Value
# 0                   Accuracy  0.5203
# 1              Precision/PPV  0.5203
# 2     Sensitivity/TPR/Recall  1.0000
# 3            Specificity/TNR  0.0000
# 4                 Error Rate  0.4797
# 5  False Positive Rate (FPR)  1.0000
# 6                    F-Score  0.6845
# (RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                         criterion='gini', max_depth=10, max_features='auto',
#                         max_leaf_nodes=None, max_samples=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=10,
#                         oob_score=False, random_state=None, verbose=0,
#                         warm_start=False), 0.0)
